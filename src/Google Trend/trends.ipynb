# %%
import pandas as pd
import ast

# %%
df=pd.read_csv("./google_trends_data_test_1/all_trends_consolidated_test.csv")

# %%
df["valeurs"] = df["values"].apply(ast.literal_eval)

# %%
def standardize(df):
    results=[]
    for i in range(len(df)):
        valeur=df.iloc[i]["valeurs"][0]["extracted_value"]
        
        results.append({
            "date":df.iloc[i]["date"],
            "keyword":df.iloc[i]["keyword"],
            "valeur":valeur
        })
    return pd.DataFrame(results)

# %%
data=standardize(df)

# %%
l=list(data["keyword"].unique())
data[data["keyword"]==l[0]][["date","valeur"]].iloc[0]["valeur"]
results=pd.DataFrame()
results["date"]=data[data["keyword"]==l[0]]["date"]

# %%
for i in range(len(l)):
    results[l[i]]=data[data["keyword"]==l[i]]["valeur"].values
# Out:
# C:\Users\masta\AppData\Local\Temp\ipykernel_2388\1862564649.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results[l[i]]=data[data["keyword"]==l[i]]["valeur"].values
# C:\Users\masta\AppData\Local\Temp\ipykernel_2388\1862564649.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   results[l[i]]=data[data["keyword"]==l[i]]["valeur"].values
# ...

# %%
results["date"]=pd.to_datetime(results["date"])
results['date'] = results['date'].dt.strftime('%m-%Y')
#results=results[~results["date"].astype(str).str.contains("2020")]
# Out:
# C:\Users\masta\AppData\Local\Temp\ipykernel_2388\2906550866.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   results["date"]=pd.to_datetime(results["date"])

# %%
#results.to_csv("trends.csv",index=False)

# %%
results2=results

# %%
results1=results

# %%
all=pd.merge(results1,results2,on="date")
